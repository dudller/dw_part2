# %%
# !pip install --upgrade tables
# !pip install eli5
# !pip instal xgboost

# %%
import pandas as pd 
import numpy as np 
from sklearn.dummy import  DummyRegressor
from sklearn.tree import  DecisionTreeRegressor
from sklearn.metrics import  mean_absolute_error as mae
from sklearn.model_selection import  cross_val_score, KFold
import eli5
from eli5.sklearn import PermutationImportance
from sklearn.ensemble import  RandomForestRegressor
import xgboost as xgb

# %%
cd '/content/drive/My Drive/Colab Notebooks/dw_matrix/part2/dw_part2'
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix/part2/dw_part2

# %%
df = pd.read_hdf('data/car.h5')

# %%
SUFFIX='__cat'
for feat in df.columns:
  if isinstance(df[feat][0],list):
    continue
  if SUFFIX in feat: continue
  else: df[feat+SUFFIX]=df[feat].factorize()[0]

# %%
cat_feats=[x for x in df.columns if SUFFIX in x]
cat_feats=[x for x in cat_feats if 'price' not in x]
len(cat_feats)
# Out:
# 151

# %%
def run_model(model,features):
  X_cat= df[features].values
  y_cat=df['price_value'].values
  scores=cross_val_score(model,X_cat,y_cat,cv=3,scoring='neg_mean_absolute_error')
  return np.mean(scores),np.std(scores)

dt_model=DecisionTreeRegressor(max_depth=5)

# %% [markdown]
# DecisionTree

# %%
run_model(dt_model,cat_feats)
# Out:
# (-19695.13091100928, 148.72570644015792)

# %% [markdown]
# Random Forest

# %%
rf_model=RandomForestRegressor(max_depth=5,n_estimators=50,random_state=0)
run_model(rf_model,cat_feats)
# Out:
# (-18718.657185256638, 64.5424578125788)

# %% [markdown]
# XGB

# %%
xgbparams={
    'max_depth': 5,
    'n_estimators': 50,
    'learning_rate': 0.1,
    'seed': 0
}
xgb_model=xgb.XGBRegressor(**xgbparams)
run_model(xgb_model,cat_feats)
# Out:
# [20:39:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# (-13108.379065811214, 74.32158265003798)

# %%
xgb_model.fit(X_cat,y_cat)
imp=PermutationImportance(xgb_model,random_state=0).fit(X_cat,y_cat)
eli5.show_weights(imp,feature_names=cat_feats)
# Out:
# [20:42:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1194
#
#                     &plusmn; 0.0031
#
#             </td>
# ...

# %%
chosen_features=['param_napęd__cat','param_rok-produkcji__cat','param_stan__cat','param_skrzynia-biegów__cat','param_faktura-vat__cat','param_moc__cat','param_marka-pojazdu__cat','feature_kamera-cofania__cat','param_typ__cat','param_pojemność-skokowa__cat','seller_name__cat','feature_wspomaganie-kierownicy__cat','param_model-pojazdu__cat','param_wersja__cat','param_kod-silnika__cat','feature_system-start-stop__cat','feature_asystent-pasa-ruchu__cat','feature_czujniki-parkowania-przednie__cat','feature_łopatki-zmiany-biegów__cat','feature_regulowane-zawieszenie__cat']

# %%
run_model(xgb_model,chosen_features)
# Out:
# [20:53:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:53:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:53:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# (-13375.230420852275, 65.40441107118909)

# %%
df['param_rok-produkcji']=df['param_rok-produkcji'].map(lambda x: -1 if str(x) == 'None' else int(x))

# %%
chosen_features2=['param_napęd__cat','param_rok-produkcji','param_stan__cat','param_skrzynia-biegów__cat','param_faktura-vat__cat','param_moc__cat','param_marka-pojazdu__cat','feature_kamera-cofania__cat','param_typ__cat','param_pojemność-skokowa__cat','seller_name__cat','feature_wspomaganie-kierownicy__cat','param_model-pojazdu__cat','param_wersja__cat','param_kod-silnika__cat','feature_system-start-stop__cat','feature_asystent-pasa-ruchu__cat','feature_czujniki-parkowania-przednie__cat','feature_łopatki-zmiany-biegów__cat','feature_regulowane-zawieszenie__cat']

# %%
run_model(xgb_model,chosen_features2)
# Out:
# [20:57:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:58:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:58:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# (-11308.885890938496, 27.868488259630677)

# %%
df['param_moc']=df['param_moc'].map(lambda x: -1 if str(x) == 'None' else int(x.split(' ')[0] ) )
chosen_features3=['param_napęd__cat','param_rok-produkcji','param_stan__cat','param_skrzynia-biegów__cat','param_faktura-vat__cat','param_moc','param_marka-pojazdu__cat','feature_kamera-cofania__cat','param_typ__cat','param_pojemność-skokowa__cat','seller_name__cat','feature_wspomaganie-kierownicy__cat','param_model-pojazdu__cat','param_wersja__cat','param_kod-silnika__cat','feature_system-start-stop__cat','feature_asystent-pasa-ruchu__cat','feature_czujniki-parkowania-przednie__cat','feature_łopatki-zmiany-biegów__cat','feature_regulowane-zawieszenie__cat']
run_model(xgb_model,chosen_features3)
# Out:
# [21:02:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:02:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:02:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# (-9716.450230340148, 62.2164408321879)

# %%
df['param_pojemność-skokowa']=df['param_pojemność-skokowa'].map(lambda x: -1 if str(x) == 'None' else int(x.split('cm')[0].replace(" ","") ) )
chosen_features4=['param_napęd__cat','param_rok-produkcji','param_stan__cat','param_skrzynia-biegów__cat','param_faktura-vat__cat','param_moc','param_marka-pojazdu__cat','feature_kamera-cofania__cat','param_typ__cat','param_pojemność-skokowa','seller_name__cat','feature_wspomaganie-kierownicy__cat','param_model-pojazdu__cat','param_wersja__cat','param_kod-silnika__cat','feature_system-start-stop__cat','feature_asystent-pasa-ruchu__cat','feature_czujniki-parkowania-przednie__cat','feature_łopatki-zmiany-biegów__cat','feature_regulowane-zawieszenie__cat']
run_model(xgb_model,chosen_features4)
# Out:
# [21:07:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:07:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:07:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# (-9569.227198767323, 72.83561801421891)
